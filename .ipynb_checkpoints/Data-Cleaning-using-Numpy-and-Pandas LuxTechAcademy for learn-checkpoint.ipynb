# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("BL-Flickr-Images-Book.csv")

# %%
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
df.shape
# Out:
# (8287, 15)

# %%
df.isnull()
# Out:
#       Identifier  Edition Statement  Place of Publication  \
# 0          False               True                 False
# 1          False               True                 False
# 2          False               True                 False
# 3          False               True                 False
# 4          False              False                 False
# ...          ...                ...                   ...
# 8282       False               True                 False
# 8283       False               True                 False
# 8284       False               True                 False
# 8285       False               True                 False
# 8286       False               True                 False
#
#       Date of Publication  Publisher  Title  Author  Contributors  \
# 0                   False      False  False   False         False
# 1                   False      False  False   False         False
# 2                   False      False  False   False         False
# ...

# %%
df.isnull().any()
# Out:
# Identifier                False
# Edition Statement          True
# Place of Publication      False
# Date of Publication        True
# Publisher                  True
# Title                     False
# Author                     True
# Contributors              False
# Corporate Author           True
# Corporate Contributors     True
# Former owner               True
# Engraver                   True
# Issuance type             False
# Flickr URL                False
# Shelfmarks                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
df = df.drop(columns=['Engraver'])

# %%
df.isnull().sum()
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
df['Identifier'].is_unique
# Out:
# True

# %%
df.duplicated().any()
# Out:
# False

# %%
df = df.drop(columns=['Corporate Author','Corporate Contributors','Former owner'])

# %%
df.isnull().sum()
# Out:
# Identifier                 0
# Edition Statement       7514
# Place of Publication       0
# Date of Publication      181
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#       Identifier Edition Statement      Place of Publication  \
# 0            206               NaN                    London
# 1            216               NaN  London; Virtue & Yorston
# 2            218               NaN                    London
# 3            472               NaN                    London
# 6            519               NaN                    London
# ...          ...               ...                       ...
# 8282     4158088               NaN                    London
# 8283     4158128               NaN                     Derby
# 8284     4159563               NaN                    London
# 8285     4159587               NaN       Newcastle upon Tyne
# 8286     4160339               NaN                    London
#
#      Date of Publication                Publisher  \
# 0            1879 [1878]         S. Tinsley & Co.
# 1                   1868             Virtue & Co.
# 2                   1869    Bradbury, Evans & Co.
# ...

# %%
is_NaN = df. isnull()
row_has_NaN = is_NaN.any(axis=1)
df[row_has_NaN]
# Out:
#       Identifier Edition Statement      Place of Publication  \
# 0            206               NaN                    London
# 1            216               NaN  London; Virtue & Yorston
# 2            218               NaN                    London
# 3            472               NaN                    London
# 6            519               NaN                    London
# ...          ...               ...                       ...
# 8282     4158088               NaN                    London
# 8283     4158128               NaN                     Derby
# 8284     4159563               NaN                    London
# 8285     4159587               NaN       Newcastle upon Tyne
# 8286     4160339               NaN                    London
#
#      Date of Publication                Publisher  \
# 0            1879 [1878]         S. Tinsley & Co.
# 1                   1868             Virtue & Co.
# 2                   1869    Bradbury, Evans & Co.
# ...

# %%
df[df.isnull()]
# Out:
#       Identifier Edition Statement Place of Publication Date of Publication  \
# 0            NaN               NaN                  NaN                 NaN
# 1            NaN               NaN                  NaN                 NaN
# 2            NaN               NaN                  NaN                 NaN
# 3            NaN               NaN                  NaN                 NaN
# 4            NaN               NaN                  NaN                 NaN
# ...          ...               ...                  ...                 ...
# 8282         NaN               NaN                  NaN                 NaN
# 8283         NaN               NaN                  NaN                 NaN
# 8284         NaN               NaN                  NaN                 NaN
# 8285         NaN               NaN                  NaN                 NaN
# 8286         NaN               NaN                  NaN                 NaN
#
# ...

# %%
df[df['Edition Statement'].isna()]
# Out:
#       Identifier Edition Statement      Place of Publication  \
# 0            206               NaN                    London
# 1            216               NaN  London; Virtue & Yorston
# 2            218               NaN                    London
# 3            472               NaN                    London
# 6            519               NaN                    London
# ...          ...               ...                       ...
# 8282     4158088               NaN                    London
# 8283     4158128               NaN                     Derby
# 8284     4159563               NaN                    London
# 8285     4159587               NaN       Newcastle upon Tyne
# 8286     4160339               NaN                    London
#
#      Date of Publication                Publisher  \
# 0            1879 [1878]         S. Tinsley & Co.
# 1                   1868             Virtue & Co.
# 2                   1869    Bradbury, Evans & Co.
# ...

# %%
df['Edition Statement'] = df['Edition Statement'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Identifier                 0
# Edition Statement          0
# Place of Publication       0
# Date of Publication      181
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                       Unknown                    London
# 1         216                       Unknown  London; Virtue & Yorston
# 2         218                       Unknown                    London
# 3         472                       Unknown                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
df[df['Date of Publication'].isnull()]
# Out:
#       Identifier Edition Statement  \
# 7            667           Unknown
# 35         11852           Unknown
# 145        55031           Unknown
# 310       124885           Unknown
# 378       156798           Unknown
# ...          ...               ...
# 8260     4077038           Unknown
# 8263     4112297           Unknown
# 8267     4113816           Unknown
# 8268     4114334           Unknown
# 8272     4115138           Unknown
#
#                                    Place of Publication Date of Publication  \
# 7                   pp. 40. G. Bryan & Co: Oxford, 1898                 NaN
# 35                   pp. 40. W. Cann: Plymouth, [1876?]                 NaN
# 145                pp. vi. 216. Hatchards: London, 1888                 NaN
# 310                  pp. 64. W. Cann: Plymouth, [1870?]                 NaN
# 378             pp. 95. Erskine Macdonald: London, 1921                 NaN
# ...                                                 ...                 ...
# ...

# %%
df_date_nan = df['Date of Publication'].isnull().sum()

# %%
df_date_count = df['Date of Publication'].count()

# %%
(df_date_count - df_date_nan)/df_date_count
# Out:
# 0.9776708610905502

# %%
df_date_nan/df_date_count
# Out:
# 0.02232913890944979
