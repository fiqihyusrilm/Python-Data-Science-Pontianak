# %%
import pandas as pd

# %%
data = pd.read_csv('Global_Mobility_Report.csv', low_memory=False)

# %%
databaru = data[data['country_region']=='Indonesia']

# %%
databaru['sub_region_1'].unique()
# Out:
# array([nan, 'Aceh', 'Bali', 'Bangka Belitung Islands', 'Banten',
#        'Bengkulu', 'Central Java', 'Central Kalimantan',
#        'Central Sulawesi', 'East Java', 'East Kalimantan',
#        'East Nusa Tenggara', 'Gorontalo', 'Jakarta', 'Jambi', 'Lampung',
#        'Maluku', 'North Kalimantan', 'North Maluku', 'North Sulawesi',
#        'North Sumatra', 'Papua', 'Riau', 'Riau Islands',
#        'South East Sulawesi', 'South Kalimantan', 'South Sulawesi',
#        'South Sumatra', 'Special Region of Yogyakarta', 'West Java',
#        'West Kalimantan', 'West Nusa Tenggara', 'West Papua',
#        'West Sulawesi', 'West Sumatra'], dtype=object)

# %%
data3
# Out:
#         country_region_code country_region  sub_region_1 iso_3166_2_code  \
# 1712211                  ID      Indonesia           NaN             NaN
# 1712212                  ID      Indonesia           NaN             NaN
# 1712213                  ID      Indonesia           NaN             NaN
# 1712214                  ID      Indonesia           NaN             NaN
# 1712215                  ID      Indonesia           NaN             NaN
# ...                     ...            ...           ...             ...
# 1724526                  ID      Indonesia  West Sumatra           ID-SB
# 1724527                  ID      Indonesia  West Sumatra           ID-SB
# 1724528                  ID      Indonesia  West Sumatra           ID-SB
# 1724529                  ID      Indonesia  West Sumatra           ID-SB
# 1724530                  ID      Indonesia  West Sumatra           ID-SB
#
#                date  retail_and_recreation_percent_change_from_baseline  \
# ...

# %%
data3 = data2.drop(columns='census_fips_code')

# %%
data1['census_fips_code'].isnull().sum()
# Out:
# 12320

# %%
data3.isnull().sum()
# Out:
# country_region_code                                     0
# country_region                                          0
# sub_region_1                                          352
# iso_3166_2_code                                       352
# date                                                    0
# retail_and_recreation_percent_change_from_baseline     50
# grocery_and_pharmacy_percent_change_from_baseline      99
# parks_percent_change_from_baseline                    118
# transit_stations_percent_change_from_baseline         404
# workplaces_percent_change_from_baseline                 0
# residential_percent_change_from_baseline                0
# dtype: int64

# %%
data3 = data3.reset_index(drop=True)

# %%
data3.to_csv('Covid Indonesia.csv')

# %%
dataset = pd.read_csv('Covid Indonesia.csv')

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                                              0
# country_region_code                                     0
# country_region                                          0
# sub_region_1                                          352
# iso_3166_2_code                                       352
# date                                                    0
# retail_and_recreation_percent_change_from_baseline     50
# grocery_and_pharmacy_percent_change_from_baseline      99
# parks_percent_change_from_baseline                    118
# transit_stations_percent_change_from_baseline         404
# workplaces_percent_change_from_baseline                 0
# residential_percent_change_from_baseline                0
# dtype: int64

# %%
dataset = dataset.drop(columns='Unnamed: 0')

# %%
dataset.groupby(dataset['sub_region_1']).sum()
# Out:
#                               retail_and_recreation_percent_change_from_baseline  \
# sub_region_1
# Aceh                                                                    -3606.0
# Bali                                                                   -12270.0
# Bangka Belitung Islands                                                 -7374.0
# Banten                                                                  -5996.0
# Bengkulu                                                                -3120.0
# Central Java                                                            -4133.0
# Central Kalimantan                                                      -6157.0
# Central Sulawesi                                                        -4062.0
# East Java                                                               -5661.0
# East Kalimantan                                                         -6761.0
# ...

# %%
dataset['sub_region_1']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 12315    West Sumatra
# 12316    West Sumatra
# 12317    West Sumatra
# 12318    West Sumatra
# 12319    West Sumatra
# Name: sub_region_1, Length: 12320, dtype: object
